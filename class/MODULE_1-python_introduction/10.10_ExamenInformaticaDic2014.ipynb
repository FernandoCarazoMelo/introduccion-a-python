# %% [markdown]
# # Examen Informática (Diciembre 2014)

# %% [markdown]
# Programar una función que nos indique si un vector es equilibrado, es decir, que existe un índice en el que se puede dividir el array en dos de forma que la suma de los elementos de un lado sea igual a la suma de los elementos del otro lado.
#
# La función tendrá la siguiente forma:
#
#                                 esEquilibrado, indice = analizarVectorEquilibrado(v)
#
# donde el argumento de entrada es un array de números enteros (v) y como argumentos de salida devuelve una variable booleana (esEquilibrado) que guardará un True si es un vector equilibrado y un False en caso contrario. El argumento de salida indice guardará el índice del elemento por el que so podría dividir el array para que sea equilibrado. En el caso de que el vector no sea equilibrado, el índice será 0.
#
# ![Ej1_fig1.png](attachment:Ej1_fig1.png)

# %% [markdown]
# En el fichero "*vectoresEquilibrados.txt*" podrá encontrar diferentes vectores que tendrá que determinar si son equilibrados o no. El formato de este fichero es el que se muestra en la siguiente figura. El primer elemento de cada fila indica el tamaño del vector y a continuación se indican los elementos del vector. De esta forma, se evitará coger los ceros del final en caso de que los haya.
#
# ![Ej1_fig2.png](attachment:Ej1_fig2.png)
#
# Con la información del fichero, se imprimirá por pantalla el siguiente mensaje para cada uno de los arrays:
#
#                                 Array: [x, x, x]. Equilibrado: True/False. Indice: x.

# %% [markdown]
# Crear un fichero "*resultados.txt*" para almacenar los resultados siguiendo el siguiente formato:
#
#                                 Información del array 1
#                                 Indice: x.
#                                 Equilibrado: True/False.
#                                 Array: [x, x, x]
#
#                                 Información del array 2
#                                 Indice: x.
#                                 Equilibrado: True/False.
#                                 Array: [x, x, x]
#
#                                 ...

# %% [markdown]
# Para terminar, resolveremos el mismo ejercicio empleando Spyder.
